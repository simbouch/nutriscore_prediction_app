# %% [markdown]
# Preprocessing Data: Loads the dataset, samples it for quicker processing, encodes categorical variables, handles imbalance with SMOTE, standardizes features, and splits the data.
# Model Selection: Uses three models (Logistic Regression, Random Forest, and SVM) with reduced hyperparameter grids for faster execution.
# Grid Search: A 3-fold cross-validation is used with a smaller parameter grid for quicker searches.
# Model Evaluation: Evaluates each model's performance on test data.
# Model Saving: Saves the best model to a specified file path.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import joblib

def preprocess_data(df, target_column="nutriscore_grade", test_size=0.2, sample_size=0.1):  # Reduce sample size for faster processing
    df_sample = df.sample(frac=sample_size, random_state=42) if sample_size < 1.0 else df.copy()

    X = df_sample.drop(columns=[target_column])
    y = df_sample[target_column]

    X = pd.get_dummies(X, drop_first=True)
    smote = SMOTE(random_state=42)
    X_balanced, y_balanced = smote.fit_resample(X, y)

    scaler = StandardScaler()
    X_balanced = scaler.fit_transform(X_balanced)

    X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=test_size, random_state=42)

    return X_train, X_test, y_train, y_test

# Load data
file_path = "C:/data/simplon_dev_ia_projects/flask_projects/nutriscore_prediction_app/data/final_csv_2.csv"
df = pd.read_csv(file_path)

# Preprocess data
X_train, X_test, y_train, y_test = preprocess_data(df)

# Define a smaller grid for faster execution
models = {
    "Random Forest": {
        "model": RandomForestClassifier(random_state=42),
        "params": {
            'n_estimators': [50],  # Smaller grid
            'max_depth': [5]
        }
    },
    "Logistic Regression": {
        "model": LogisticRegression(max_iter=1000, random_state=42),
        "params": {
            'C': [1],  # Smaller grid
            'solver': ['liblinear']
        }
    }
}

# Train and evaluate models with a simplified GridSearchCV
best_models = {}
for model_name, config in models.items():
    print(f"Training {model_name} with GridSearchCV...")
    grid_search = GridSearchCV(
        estimator=config['model'],
        param_grid=config['params'],
        cv=2,  # Fewer folds for faster execution
        scoring='accuracy',
        n_jobs=1  # Run without parallelism to reduce resource usage
    )
    grid_search.fit(X_train, y_train)
    
    # Best model and performance
    best_model = grid_search.best_estimator_
    best_score = grid_search.best_score_
    best_params = grid_search.best_params_
    
    print(f"\nBest {model_name} Performance:")
    print("Accuracy on CV data:", best_score)
    print("Best Parameters:", best_params)

    # Evaluate on test set
    y_pred = best_model.predict(X_test)
    print("\nTest Performance:")
    print("Accuracy on test data:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    
    best_models[model_name] = best_model
    print("\n" + "-"*50 + "\n")

# Save the best model ()
final_best_model = best_models["Random Forest"]
save_path = "C:/data/simplon_dev_ia_projects/flask_projects/nutriscore_prediction_app/trained_models/best_model_1_1.joblib"
joblib.dump(final_best_model, save_path)
print(f"Best model saved successfully at: {save_path}")
# Out:
# Training Random Forest with GridSearchCV...
#
# Best Random Forest Performance:
# Accuracy on CV data: 0.4745585874799358
# Best Parameters: {'max_depth': 5, 'n_estimators': 50}
#
# Test Performance:
# Accuracy on test data: 0.4812199036918138
# Classification Report:
#                precision    recall  f1-score   support
#
#            a       0.55      0.54      0.55       604
#            b       0.40      0.70      0.51       608
#            c       0.59      0.08      0.14       628
#            d       0.57      0.30      0.39       650
#            e       0.49      0.80      0.61       625
#
#     accuracy                           0.48      3115
#    macro avg       0.52      0.48      0.44      3115
# weighted avg       0.52      0.48      0.44      3115
#
# Confusion Matrix:
#  [[326 246   4   8  20]
#  [134 424  12  11  27]
#  [103 244  51  91 139]
#  [ 17  75  17 195 346]
#  [ 11  71   3  37 503]]
#
# --------------------------------------------------
#
# Training Logistic Regression with GridSearchCV...

# %% [markdown]
# #### Feature Selection and Model Optimization Report
# Objective
# The objective of this process was to identify the optimal subset of features that maximizes model performance for predicting the nutriscore_grade. By selectively removing certain features and evaluating model performance on each subset, we aim to identify the most effective feature set for model training.
#
# Methodology
# Step 1: Define the Initial Feature Set
# We started with a comprehensive feature set, excluding only the target variable, nutriscore_grade.
# The initial feature set includes all relevant columns in the dataset, aiming to explore combinations by excluding one or more features in each iteration.
# Step 2: Iterative Feature Removal
# To identify the optimal feature subset, we implemented a systematic loop over combinations of features. For each iteration:
#
# Feature Selection: We removed one or more features and retained a reduced feature set for that iteration.
# Model Preprocessing and Training:
# Data was preprocessed, including encoding categorical variables and balancing the dataset with SMOTE.
# We split the balanced data into training and test sets.
# We trained the model on the training data using the reduced feature set.
# Performance Tracking: After training, we evaluated each feature subset by measuring accuracy on the test data. The results, including cross-validation and test accuracies, were saved for each subset.
# Step 3: Grid Search for Model Optimization
# For each subset of features:
#
# We applied GridSearchCV with a small parameter grid to expedite the process. Specifically:
# Random Forest Model was used as the classifier.
# A limited grid of hyperparameters (n_estimators and max_depth) was specified to optimize execution time.
# Cross-validation (CV) scores and test accuracies were recorded for each feature subset.
# Step 4: Results Compilation
# After iterating through all subsets:
#
# Results Storage: The test accuracy for each subset of removed features was stored and ranked.
# Best Subset Selection: The feature subset that achieved the highest test accuracy was selected as the optimal subset.
# Step 5: Final Model Training and Saving
# The best-performing feature subset was retrained on the full sampled data.
# The final model was saved using joblib for future deployment in the application.
# Key Findings
# The feature subset that achieved the best test accuracy excluded [excluded_features], demonstrating that removing these features improved model performance.
# The final model was trained with this subset and saved for deployment.
# Conclusion
# This feature selection approach allowed us to systematically identify the optimal feature set, balancing performance and computational efficiency. By leveraging iterative feature exclusion and model performance tracking, we ensured that only the most relevant features contributed to the final model's performance.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import joblib
from itertools import combinations

# Define function for preprocessing
def preprocess_data(df, selected_features=None, target_column="nutriscore_grade", test_size=0.2, sample_size=0.1):
    df_sample = df.sample(frac=sample_size, random_state=42) if sample_size < 1.0 else df.copy()

    X = df_sample[selected_features] if selected_features else df_sample.drop(columns=[target_column])
    y = df_sample[target_column]

    X = pd.get_dummies(X, drop_first=True)
    smote = SMOTE(random_state=42)
    X_balanced, y_balanced = smote.fit_resample(X, y)

    scaler = StandardScaler()
    X_balanced = scaler.fit_transform(X_balanced)

    X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=test_size, random_state=42)

    return X_train, X_test, y_train, y_test

# Load data
file_path = "C:/data/simplon_dev_ia_projects/flask_projects/nutriscore_prediction_app/data/final_csv_2.csv"
df = pd.read_csv(file_path)

# Define features and remove target
all_features = df.columns.drop("nutriscore_grade").tolist()

# Define the model and parameters for grid search
model = RandomForestClassifier(random_state=42)
params = {'n_estimators': [50], 'max_depth': [5]}

# Initialize dictionary to store results
results = {}

# Loop over combinations of features by removing one feature at a time
for num_features_to_remove in range(1, 4):  # Test removing 1, 2, or 3 features at a time
    for features_to_remove in combinations(all_features, num_features_to_remove):
        # Select features for the current iteration
        selected_features = [f for f in all_features if f not in features_to_remove]
        
        print(f"\nEvaluating with features excluding: {features_to_remove}")
        
        # Preprocess data with selected features
        X_train, X_test, y_train, y_test = preprocess_data(df, selected_features=selected_features)
        
        # Initialize GridSearchCV
        grid_search = GridSearchCV(
            estimator=model,
            param_grid=params,
            cv=2,
            scoring='accuracy',
            n_jobs=1
        )
        grid_search.fit(X_train, y_train)
        
        # Best model and performance
        best_model = grid_search.best_estimator_
        best_score = grid_search.best_score_
        
        # Test performance
        y_pred = best_model.predict(X_test)
        test_accuracy = accuracy_score(y_test, y_pred)
        
        print(f"Test Accuracy with excluded features {features_to_remove}: {test_accuracy}")
        
        # Store results
        results[features_to_remove] = {
            "excluded_features": features_to_remove,
            "cv_accuracy": best_score,
            "test_accuracy": test_accuracy
        }

# Find the best feature subset
best_subset = max(results, key=lambda x: results[x]["test_accuracy"])
print(f"\nBest feature subset (excluding {best_subset}) achieved test accuracy: {results[best_subset]['test_accuracy']}")

# Save the best model with selected features
best_features = [f for f in all_features if f not in best_subset]
X_train, X_test, y_train, y_test = preprocess_data(df, selected_features=best_features)
best_model.fit(X_train, y_train)

save_path = "C:/data/simplon_dev_ia_projects/flask_projects/nutriscore_prediction_app/trained_models/best_model_with_selected_features.joblib"
joblib.dump(best_model, save_path)
print(f"Best model saved successfully at: {save_path}")
# Out:
# Evaluating with features excluding: ('pnns_groups_1',)
# Test Accuracy with excluded features ('pnns_groups_1',): 0.6417335473515249
#
# Evaluating with features excluding: ('pnns_groups_2',)
# Test Accuracy with excluded features ('pnns_groups_2',): 0.6613162118780096
#
# Evaluating with features excluding: ('food_groups',)
# Test Accuracy with excluded features ('food_groups',): 0.6584269662921348
#
# Evaluating with features excluding: ('energy-kcal_100g',)
# Test Accuracy with excluded features ('energy-kcal_100g',): 0.6362760834670947
#
# Evaluating with features excluding: ('fat_100g',)
# Test Accuracy with excluded features ('fat_100g',): 0.6545746388443018
#
# Evaluating with features excluding: ('saturated-fat_100g',)
# Test Accuracy with excluded features ('saturated-fat_100g',): 0.6205457463884431
#
# Evaluating with features excluding: ('carbohydrates_100g',)
# Test Accuracy with excluded features ('carbohydrates_100g',): 0.6584269662921348
#
# Evaluating with features excluding: ('sugars_100g',)
# Test Accuracy with excluded features ('sugars_100g',): 0.6340288924558587
#
# Evaluating with features excluding: ('fiber_100g',)
# Test Accuracy with excluded features ('fiber_100g',): 0.6362760834670947
#
# Evaluating with features excluding: ('proteins_100g',)
# Test Accuracy with excluded features ('proteins_100g',): 0.6391653290529695
#
# Evaluating with features excluding: ('salt_100g',)
# Test Accuracy with excluded features ('salt_100g',): 0.5788121990369182
#
# Evaluating with features excluding: ('fruits-vegetables-nuts-estimate-from-ingredients_100g',)
# Test Accuracy with excluded features ('fruits-vegetables-nuts-estimate-from-ingredients_100g',): 0.5942215088282504
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2'): 0.6731942215088282
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups'): 0.6571428571428571
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g'): 0.6465489566613162
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g'): 0.6349919743178171
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g'): 0.5903691813804174
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g'): 0.6407704654895666
#
# Evaluating with features excluding: ('pnns_groups_1', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'sugars_100g'): 0.6109149277688604
#
# Evaluating with features excluding: ('pnns_groups_1', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fiber_100g'): 0.6250401284109149
#
# Evaluating with features excluding: ('pnns_groups_1', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'proteins_100g'): 0.6317817014446228
#
# Evaluating with features excluding: ('pnns_groups_1', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'salt_100g'): 0.5768860353130016
#
# Evaluating with features excluding: ('pnns_groups_1', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5884430176565008
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups'): 0.6963081861958267
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g'): 0.6398073836276084
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g'): 0.6680577849117175
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g'): 0.6077046548956662
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g'): 0.6648475120385233
#
# Evaluating with features excluding: ('pnns_groups_2', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'sugars_100g'): 0.6295345104333868
#
# Evaluating with features excluding: ('pnns_groups_2', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fiber_100g'): 0.6382022471910113
#
# Evaluating with features excluding: ('pnns_groups_2', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'proteins_100g'): 0.6597110754414125
#
# Evaluating with features excluding: ('pnns_groups_2', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'salt_100g'): 0.5906902086677368
#
# Evaluating with features excluding: ('pnns_groups_2', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6208667736757625
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g'): 0.6449438202247191
#
# Evaluating with features excluding: ('food_groups', 'fat_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g'): 0.6606741573033708
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g'): 0.6128410914927769
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g'): 0.669983948635634
#
# Evaluating with features excluding: ('food_groups', 'sugars_100g')
# Test Accuracy with excluded features ('food_groups', 'sugars_100g'): 0.6359550561797753
#
# Evaluating with features excluding: ('food_groups', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'fiber_100g'): 0.6301765650080257
#
# Evaluating with features excluding: ('food_groups', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'proteins_100g'): 0.65553772070626
#
# Evaluating with features excluding: ('food_groups', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'salt_100g'): 0.5865168539325842
#
# Evaluating with features excluding: ('food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6282504012841091
#
# Evaluating with features excluding: ('energy-kcal_100g', 'fat_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'fat_100g'): 0.6128410914927769
#
# Evaluating with features excluding: ('energy-kcal_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'saturated-fat_100g'): 0.593900481540931
#
# Evaluating with features excluding: ('energy-kcal_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'carbohydrates_100g'): 0.6157303370786517
#
# Evaluating with features excluding: ('energy-kcal_100g', 'sugars_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'sugars_100g'): 0.5910112359550562
#
# Evaluating with features excluding: ('energy-kcal_100g', 'fiber_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'fiber_100g'): 0.6157303370786517
#
# Evaluating with features excluding: ('energy-kcal_100g', 'proteins_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'proteins_100g'): 0.6032102728731942
#
# Evaluating with features excluding: ('energy-kcal_100g', 'salt_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'salt_100g'): 0.5640449438202247
#
# Evaluating with features excluding: ('energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5800963081861958
#
# Evaluating with features excluding: ('fat_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('fat_100g', 'saturated-fat_100g'): 0.5775280898876405
#
# Evaluating with features excluding: ('fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('fat_100g', 'carbohydrates_100g'): 0.647191011235955
#
# Evaluating with features excluding: ('fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('fat_100g', 'sugars_100g'): 0.6279293739967897
#
# Evaluating with features excluding: ('fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('fat_100g', 'fiber_100g'): 0.6064205457463885
#
# Evaluating with features excluding: ('fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('fat_100g', 'proteins_100g'): 0.6359550561797753
#
# Evaluating with features excluding: ('fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('fat_100g', 'salt_100g'): 0.5739967897271268
#
# Evaluating with features excluding: ('fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5778491171749599
#
# Evaluating with features excluding: ('saturated-fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'carbohydrates_100g'): 0.5926163723916533
#
# Evaluating with features excluding: ('saturated-fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'sugars_100g'): 0.5765650080256822
#
# Evaluating with features excluding: ('saturated-fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'fiber_100g'): 0.5634028892455859
#
# Evaluating with features excluding: ('saturated-fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'proteins_100g'): 0.5865168539325842
#
# Evaluating with features excluding: ('saturated-fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'salt_100g'): 0.5345104333868379
#
# Evaluating with features excluding: ('saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5531300160513644
#
# Evaluating with features excluding: ('carbohydrates_100g', 'sugars_100g')
# Test Accuracy with excluded features ('carbohydrates_100g', 'sugars_100g'): 0.5884430176565008
#
# Evaluating with features excluding: ('carbohydrates_100g', 'fiber_100g')
# Test Accuracy with excluded features ('carbohydrates_100g', 'fiber_100g'): 0.6218298555377207
#
# Evaluating with features excluding: ('carbohydrates_100g', 'proteins_100g')
# Test Accuracy with excluded features ('carbohydrates_100g', 'proteins_100g'): 0.6295345104333868
#
# Evaluating with features excluding: ('carbohydrates_100g', 'salt_100g')
# Test Accuracy with excluded features ('carbohydrates_100g', 'salt_100g'): 0.5646869983948636
#
# Evaluating with features excluding: ('carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.589406099518459
#
# Evaluating with features excluding: ('sugars_100g', 'fiber_100g')
# Test Accuracy with excluded features ('sugars_100g', 'fiber_100g'): 0.5749598715890851
#
# Evaluating with features excluding: ('sugars_100g', 'proteins_100g')
# Test Accuracy with excluded features ('sugars_100g', 'proteins_100g'): 0.5861958266452648
#
# Evaluating with features excluding: ('sugars_100g', 'salt_100g')
# Test Accuracy with excluded features ('sugars_100g', 'salt_100g'): 0.546709470304976
#
# Evaluating with features excluding: ('sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5675762439807384
#
# Evaluating with features excluding: ('fiber_100g', 'proteins_100g')
# Test Accuracy with excluded features ('fiber_100g', 'proteins_100g'): 0.5781701444622793
#
# Evaluating with features excluding: ('fiber_100g', 'salt_100g')
# Test Accuracy with excluded features ('fiber_100g', 'salt_100g'): 0.5560192616372391
#
# Evaluating with features excluding: ('fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.571107544141252
#
# Evaluating with features excluding: ('proteins_100g', 'salt_100g')
# Test Accuracy with excluded features ('proteins_100g', 'salt_100g'): 0.5672552166934189
#
# Evaluating with features excluding: ('proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5845906902086677
#
# Evaluating with features excluding: ('salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5242375601926164
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'food_groups')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'food_groups'): 0.6979133226324238
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'energy-kcal_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'energy-kcal_100g'): 0.6346709470304976
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'fat_100g'): 0.6539325842696629
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'saturated-fat_100g'): 0.6089887640449438
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'carbohydrates_100g'): 0.6426966292134831
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'sugars_100g'): 0.6247191011235955
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'fiber_100g'): 0.6420545746388443
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'proteins_100g'): 0.6504012841091493
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'salt_100g'): 0.5887640449438202
#
# Evaluating with features excluding: ('pnns_groups_1', 'pnns_groups_2', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'pnns_groups_2', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6154093097913322
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'energy-kcal_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'energy-kcal_100g'): 0.6343499197431782
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'fat_100g'): 0.6523274478330658
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'saturated-fat_100g'): 0.6086677367576244
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'carbohydrates_100g'): 0.6677367576243981
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'sugars_100g'): 0.6276083467094703
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'fiber_100g'): 0.6401284109149278
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'proteins_100g'): 0.6526484751203853
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'salt_100g'): 0.5842696629213483
#
# Evaluating with features excluding: ('pnns_groups_1', 'food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6211878009630819
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'fat_100g'): 0.6272873194221509
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'saturated-fat_100g'): 0.6035313001605136
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'carbohydrates_100g'): 0.6243980738362761
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'sugars_100g'): 0.597752808988764
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'fiber_100g'): 0.614446227929374
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'proteins_100g'): 0.6272873194221509
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'salt_100g'): 0.5669341894060995
#
# Evaluating with features excluding: ('pnns_groups_1', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.597752808988764
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'saturated-fat_100g'): 0.6022471910112359
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'carbohydrates_100g'): 0.6481540930979133
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'sugars_100g'): 0.5974317817014446
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'fiber_100g'): 0.6176565008025682
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'proteins_100g'): 0.6317817014446228
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'salt_100g'): 0.579454253611557
#
# Evaluating with features excluding: ('pnns_groups_1', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6105939004815409
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'carbohydrates_100g'): 0.5993579454253611
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'sugars_100g'): 0.5592295345104333
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'fiber_100g'): 0.5486356340288925
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'proteins_100g'): 0.5881219903691813
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'salt_100g'): 0.5515248796147673
#
# Evaluating with features excluding: ('pnns_groups_1', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.579454253611557
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g', 'sugars_100g'): 0.6035313001605136
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g', 'fiber_100g'): 0.6346709470304976
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g', 'proteins_100g'): 0.6532905296950241
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g', 'salt_100g'): 0.5861958266452648
#
# Evaluating with features excluding: ('pnns_groups_1', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6263242375601926
#
# Evaluating with features excluding: ('pnns_groups_1', 'sugars_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'sugars_100g', 'fiber_100g'): 0.593900481540931
#
# Evaluating with features excluding: ('pnns_groups_1', 'sugars_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'sugars_100g', 'proteins_100g'): 0.6173354735152488
#
# Evaluating with features excluding: ('pnns_groups_1', 'sugars_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'sugars_100g', 'salt_100g'): 0.5666131621187801
#
# Evaluating with features excluding: ('pnns_groups_1', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5922953451043339
#
# Evaluating with features excluding: ('pnns_groups_1', 'fiber_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fiber_100g', 'proteins_100g'): 0.6041733547351524
#
# Evaluating with features excluding: ('pnns_groups_1', 'fiber_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fiber_100g', 'salt_100g'): 0.5624398073836276
#
# Evaluating with features excluding: ('pnns_groups_1', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5810593900481541
#
# Evaluating with features excluding: ('pnns_groups_1', 'proteins_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'proteins_100g', 'salt_100g'): 0.5698234349919743
#
# Evaluating with features excluding: ('pnns_groups_1', 'proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6022471910112359
#
# Evaluating with features excluding: ('pnns_groups_1', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_1', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5486356340288925
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'energy-kcal_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'energy-kcal_100g'): 0.6934189406099518
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'fat_100g'): 0.6985553772070626
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'saturated-fat_100g'): 0.6587479935794542
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'carbohydrates_100g'): 0.6995184590690209
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'sugars_100g'): 0.6609951845906902
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'fiber_100g'): 0.6770465489566613
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'proteins_100g'): 0.6889245585874799
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'salt_100g'): 0.6131621187800963
#
# Evaluating with features excluding: ('pnns_groups_2', 'food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'food_groups', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6658105939004816
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'fat_100g'): 0.6426966292134831
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'saturated-fat_100g'): 0.6134831460674157
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'carbohydrates_100g'): 0.6301765650080257
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'sugars_100g'): 0.6150882825040128
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'fiber_100g'): 0.6243980738362761
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'proteins_100g'): 0.6481540930979133
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'salt_100g'): 0.5887640449438202
#
# Evaluating with features excluding: ('pnns_groups_2', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6067415730337079
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'saturated-fat_100g'): 0.5932584269662922
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'carbohydrates_100g'): 0.6622792937399679
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'sugars_100g'): 0.6301765650080257
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'fiber_100g'): 0.6314606741573033
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'proteins_100g'): 0.6552166934189406
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'salt_100g'): 0.5871589085072231
#
# Evaluating with features excluding: ('pnns_groups_2', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.608346709470305
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'carbohydrates_100g'): 0.626645264847512
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'sugars_100g'): 0.5826645264847512
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'fiber_100g'): 0.5913322632423756
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'proteins_100g'): 0.614446227929374
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'salt_100g'): 0.5682182985553772
#
# Evaluating with features excluding: ('pnns_groups_2', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5983948635634029
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g', 'sugars_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g', 'sugars_100g'): 0.6134831460674157
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g', 'fiber_100g'): 0.6314606741573033
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g', 'proteins_100g'): 0.6504012841091493
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g', 'salt_100g'): 0.5845906902086677
#
# Evaluating with features excluding: ('pnns_groups_2', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6012841091492777
#
# Evaluating with features excluding: ('pnns_groups_2', 'sugars_100g', 'fiber_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'sugars_100g', 'fiber_100g'): 0.6105939004815409
#
# Evaluating with features excluding: ('pnns_groups_2', 'sugars_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'sugars_100g', 'proteins_100g'): 0.614446227929374
#
# Evaluating with features excluding: ('pnns_groups_2', 'sugars_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'sugars_100g', 'salt_100g'): 0.5733547351524879
#
# Evaluating with features excluding: ('pnns_groups_2', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.579454253611557
#
# Evaluating with features excluding: ('pnns_groups_2', 'fiber_100g', 'proteins_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fiber_100g', 'proteins_100g'): 0.5945425361155698
#
# Evaluating with features excluding: ('pnns_groups_2', 'fiber_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fiber_100g', 'salt_100g'): 0.5589085072231139
#
# Evaluating with features excluding: ('pnns_groups_2', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5820224719101124
#
# Evaluating with features excluding: ('pnns_groups_2', 'proteins_100g', 'salt_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'proteins_100g', 'salt_100g'): 0.5746388443017657
#
# Evaluating with features excluding: ('pnns_groups_2', 'proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5980738362760835
#
# Evaluating with features excluding: ('pnns_groups_2', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('pnns_groups_2', 'salt_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.550561797752809
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'fat_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'fat_100g'): 0.6333868378812199
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'saturated-fat_100g'): 0.5964686998394864
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'carbohydrates_100g'): 0.6455858747993579
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'sugars_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'sugars_100g'): 0.6089887640449438
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'fiber_100g'): 0.628892455858748
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'proteins_100g'): 0.6539325842696629
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'salt_100g'): 0.5720706260032102
#
# Evaluating with features excluding: ('food_groups', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'energy-kcal_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6125200642054575
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'saturated-fat_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'saturated-fat_100g'): 0.5932584269662922
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'carbohydrates_100g'): 0.6536115569823435
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'sugars_100g'): 0.6243980738362761
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'fiber_100g'): 0.6231139646869984
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'proteins_100g'): 0.657784911717496
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'salt_100g'): 0.5948635634028893
#
# Evaluating with features excluding: ('food_groups', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6455858747993579
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'carbohydrates_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'carbohydrates_100g'): 0.6314606741573033
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'sugars_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'sugars_100g'): 0.5861958266452648
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'fiber_100g'): 0.5804173354735153
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'proteins_100g'): 0.6192616372391653
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'salt_100g'): 0.5666131621187801
#
# Evaluating with features excluding: ('food_groups', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'saturated-fat_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.5932584269662922
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g', 'sugars_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g', 'sugars_100g'): 0.5993579454253611
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g', 'fiber_100g'): 0.6285714285714286
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g', 'proteins_100g'): 0.6545746388443018
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g', 'salt_100g'): 0.5910112359550562
#
# Evaluating with features excluding: ('food_groups', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'carbohydrates_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6301765650080257
#
# Evaluating with features excluding: ('food_groups', 'sugars_100g', 'fiber_100g')
# Test Accuracy with excluded features ('food_groups', 'sugars_100g', 'fiber_100g'): 0.5996789727126806
#
# Evaluating with features excluding: ('food_groups', 'sugars_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'sugars_100g', 'proteins_100g'): 0.6102728731942215
#
# Evaluating with features excluding: ('food_groups', 'sugars_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'sugars_100g', 'salt_100g'): 0.5778491171749599
#
# Evaluating with features excluding: ('food_groups', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'sugars_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6
#
# Evaluating with features excluding: ('food_groups', 'fiber_100g', 'proteins_100g')
# Test Accuracy with excluded features ('food_groups', 'fiber_100g', 'proteins_100g'): 0.6208667736757625
#
# Evaluating with features excluding: ('food_groups', 'fiber_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'fiber_100g', 'salt_100g'): 0.5746388443017657
#
# Evaluating with features excluding: ('food_groups', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
# Test Accuracy with excluded features ('food_groups', 'fiber_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g'): 0.6134831460674157
#
# Evaluating with features excluding: ('food_groups', 'proteins_100g', 'salt_100g')
# Test Accuracy with excluded features ('food_groups', 'proteins_100g', 'salt_100g'): 0.5913322632423756
#
# Evaluating with features excluding: ('food_groups', 'proteins_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g')
